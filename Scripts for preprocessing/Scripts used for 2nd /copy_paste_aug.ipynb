# %%
# path:/home/aayush/Documents/Dataset Manipulation/Edited/f/test

"""
Write script to:

Extract truck crops from labeled data

Write script to:

Select low-density background images

Write script to:

Paste 1 truck onto 1 background
"""
# Out:
# '\nWrite script to:\n\nExtract truck crops from labeled data\n\nWrite script to:\n\nSelect low-density background images\n\nWrite script to:\n\nPaste 1 truck onto 1 background\n'

# %%
from pathlib import Path

# %%
labels_path = Path("/home/aayush/Documents/Dataset Manipulation/Edited/A1 Post Merge(Fixed + Removed Classes + Both lanes)/train/labels")
images_path = Path("/home/aayush/Documents/Dataset Manipulation/Edited/A1 Post Merge(Fixed + Removed Classes + Both lanes)/train/images")

# %%
target_id_6 = "6" # Bcz part[0] gives string not int
target_id_5 = "5"
boxes_6 = {}
boxes_5 = {}
for label in labels_path.iterdir():
    with open(label) as f:
        for line in f:
            parts = line.strip().split()
            if parts[0] == target_id_6:
                bbox_6 = list(map(float, parts[1:]))
                if label.stem not in boxes_6:
                    boxes_6[label.stem] = []
                    boxes_6[label.stem].append(bbox_6)
            elif parts[0] == target_id_5:
                bbox_5 = list(map(float, parts[1:]))
                if label.stem not in boxes_5:
                    boxes_5[label.stem] = []
                    boxes_5[label.stem].append(bbox_5)

print(boxes_6)
print(len(boxes_6))
print(bbox_6)
print(boxes_5)
print(len(boxes_5))
# Out:
# {'frame250_jpg.rf.f5efeede7d7e04fd400a582ecaa1d057': [[0.8890625000000001, 0.8770833333333333, 0.209375, 0.25]], 'frame476_jpg.rf.e153b908ae8557ee656dc3f57acdd75a': [[0.24921875000000002, 0.7364583333333333, 0.15781250000000002, 0.3020833333333333]], 'frame509_jpg.rf.bf5bd7ff26532d19f32176caf1fa368b': [[0.02109375, 0.8239583333333333, 0.0390625, 0.34375]], 'frame299_jpg.rf.13b9577fcb8bda31cfd82b90222f0cbf': [[0.11093750000000001, 0.9208333333333333, 0.146875, 0.15416666666666667]], 'frame4_jpg.rf.ff653a37042eb9f45085e3d2455f0132': [[0.42031250000000003, 0.875, 0.115625, 0.25416666666666665]], 'frame14_jpg.rf.9ad757ac1e492a3def12b53dfc8ca0c7': [[0.8703125, 0.7770833333333333, 0.2625, 0.4458333333333333]], 'frame21_jpg.rf.2fa080b282206108d4ee3f618bbbfa06': [[0.81953125, 0.7510416666666666, 0.2671875, 0.35625]], 'frame276_jpg.rf.7d593bc74270b1a1e66fd0d523dcca48': [[0.18359375, 0.7104166666666667, 0.2265625, 0.325]], 'frame295_jpg.rf.d07633c83a57f7662aa21803fa2afd18': [[0.039843750000000004, 0.8333333333333334, 0.0765625, 0.3375]], 'frame335_jpg.rf.55237ee8c625c89d5d25030cb7614220': [[0.146875, 0.625, 0.284375, 0.43333333333333335]], 'frame388_jpg.rf.24565f9eae204fecaa6119fb76d73b6b': [[0.07500000000000001, 0.7770833333333333, 0.146875, 0.45]], 'frame42_jpg.rf.a4a4bb04066fcbb8eaace876a52e53
cc53a9c509': [[0.309375, 0.7625, 0.09375, 0.24166666666666667]], 'frame326_jpg.rf.c02a56887041a56eaef7bbf6c83ed83d': [[0.3296875, 0.6552083333333333, 0.084375, 0.20208333333333334]], 'frame327_jpg.rf.f4f665771cc7d0203769c35f8969cd49': [[0.340625, 0.6041666666666666, 0.06875, 0.175]], 'frame328_jpg.rf.7f70a7fe81662eec360752fd89d5de55': [[0.328125, 0.5625, 0.0625, 0.14583333333333334]], 'frame329_jpg.rf.b06e7cc3439811eb39ff36f17e05b044': [[0.34218750000000003, 0.4479166666666667, 0.05625, 0.11666666666666667]], 'frame334_jpg.rf.86ee9f2c600f93e5adaa7177d3c30950': [[0.28125, 0.34270833333333334, 0.043750000000000004, 0.08958333333333333]], 'frame335_jpg.rf.a1310a55e4c2220c266f6fde7e38099f': [[0.24453125, 0.34791666666666665, 0.0421875, 0.0875]], 'frame336_jpg.rf.b3c5302189438f3bf34a82f7142ae35a': [[0.21250000000000002, 0.3416666666666667, 0.037500000000000006, 0.0875]], 'frame337_jpg.rf.6789d7ce4f0e461ad715244b904fb995': [[0.25390625, 0.3375, 0.0390625, 0.09166666666666666]], 'frame338_jpg.rf.d86a48959e799e0cc3d7342f0efaabca': [[0.2609375, 0.321875, 0.03125, 0.07708333333333334]], 'frame340_jpg.rf.24c5279917cd0355ed7392d9ba37fe9c': [[0.10312500000000001, 0.9489583333333333, 0.178125, 0.10208333333333333]], 'frame341_jpg.rf.ca60c0f0c133f626ab2cc299498895a2': [[0.20078125000000002, 0.803125, 0.11093750000000001, 0.23958333333333334]], 'frame342_jpg.rf.d6b366e7be68b7479f35440d1ecaf8cf': [[0.25, 0.6239583333333333, 0.084375, 0.19375]], 'frame344_jpg.rf.f6fd534cf5ad6ac16abc4fd5c15991b5': [[0.27109375, 0.54375, 0.060937500000000006, 0.1375]], 'frame346_jpg.rf.b281bab5cca35c7a0162778bf75356f9': [[0.4296875, 0.6177083333333333, 0.1, 0.22291666666666665]], 'frame349_jpg.rf.d0ba4449ab96cd4ad7564412bd6b1fe8': [[0.40078125000000003, 0.5125, 0.0890625, 0.19166666666666665]], 'frame352_jpg.rf.136a3c04c431f435b5a82d37b73643a7': ...
# 3123

# %%
def bbox_conv(bounding_boxes) -> tuple[float, float, float, float]:
    size = (640, 480)

    cx, cy, w, h = bounding_boxes
    cx *= size[0]
    cy *= size[1]
    w *= size[0]
    h *= size[1]

    xmin = cx - w / 2
    ymin = cy - h / 2
    xmax = cx + w / 2
    ymax = cy + h / 2

    return xmin, ymin, xmax, ymax

# %%
index = 0
for photo in images_path.iterdir():
    if photo.stem in boxes_6:
        for a in len(boxes_6[photo.stem]):

# %% [markdown]
# Next steps:
#
# 1. Make function for bbox conversion
# 2. USe that function above now
# 3. Use the converted stuff to crop
# 4. Name the cropped image by index and ++ the value
# 5. Put that shi in a directory for class 6
# 6. Do same stuff for class 5
