# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.3 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
if torch.cuda.is_available():
  device = "cuda"
elif torch.backends.mps.is_available():
  device = "mps"
else:
  device = "cpu"
print(device)
# Out:
# cuda

# %%
# for aayushghale47
# !unzip -q "/content/drive/MyDrive/3rd defence/A1.zip"

# %%
model = YOLO("/content/drive/MyDrive/3rd defence/yolo11s.pt")

# %%
model = YOLO("/content/drive/MyDrive/3rd defence/train2/weights/last.pt")

# %%
#sumans config

results = model.train(
      data="/content/A1 Post Merge(Fixed + Removed Classes + Both lanes)/data.yaml",
      epochs=90,
      device=device,
      imgsz=640,
      batch=32,
      optimizer="AdamW",
      lr0=0.005,
      lrf=0.01,
      warmup_epochs=3,
      patience=20,
      save=True,
      save_period=5,
      amp=True,
      workers=3,
      project="/content/drive/MyDrive/3rd defence/",
  )
# Out:
# Ultralytics 8.4.5 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.train(resume=True)
# Out:
# Ultralytics 8.4.5 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results = model.train(
      data="/content/A1 Post Merge(Fixed + Removed Classes + Both lanes)/data.yaml",
      epochs=1,
      device=device,
      imgsz=640,
      batch=32,
      amp=True,
      pretrained=True,
      workers=3,

  )
# Out:
# Ultralytics 8.4.5 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
#sumans config + custom augmentation

results = model.train(
      data="/content/A1 Post Merge(Fixed + Removed Classes + Both lanes)/data.yaml",
      epochs=90,
      device=device,
      imgsz=640,
      batch=32,
      optimizer="AdamW",
      lr0=0.005,
      lrf=0.01,
      warmup_epochs=3,
      patience=20,
      save=True,
      save_period=5,
      amp=True,
      workers=3,
    # augmentation parameters
      mosaic=0.8,
      mixup=0.3,
      hsv_h=0.02,
      hsv_s=0.5,
      hsv_v=0.3,
      translate=0.1,
      scale=0.3,
      fliplr=0.5,
      flipud=0.0,
      auto_augment=None,
      erasing=0.1,
      project="/content/drive/MyDrive/3rd defence/",
  )
# Out:
# Ultralytics 8.4.5 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
